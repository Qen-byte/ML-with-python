# %% [markdown]
# <a href="https://colab.research.google.com/github/Qen-byte/AI-search-algorithms/blob/main/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x= 2 * np.random.rand(200,1)
y=4 + 3 * x + np.random.randn(200,1)

# %%
plt.plot(x,y,'.r')

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_,model.intercept_
# Out:
# (array([[3.13483703]]), array([3.85144818]))

# %%
predictions = model.predict(x)  # Predict y for all x values in the dataset
print(predictions)
# Out:
# [[ 5.24767818]
#  [ 4.34751376]
#  [ 8.61692693]
#  [ 4.02960397]
#  [ 5.87180538]
#  [ 9.13928884]
#  [ 4.48004093]
#  [ 6.40614923]
#  [ 7.298987  ]
#  [ 8.6172582 ]
#  [ 9.766007  ]
#  [ 6.23175375]
#  [ 5.6065926 ]
#  [ 4.82624957]
#  [ 6.1885366 ]
#  [ 8.99987199]
#  [ 8.78019943]
#  [ 5.66343682]
#  [ 6.01866728]
#  [ 5.10117437]
#  [ 8.58250957]
#  [ 7.17673475]
#  [ 8.99004917]
#  [ 6.89619938]
#  [ 4.45922209]
#  [ 9.90774973]
#  [ 4.98407353]
#  [ 5.17735796]
#  [ 7.03614138]
#  [ 8.6656042 ]
#  [ 5.02434595]
#  [ 9.12613124]
#  [ 7.23498445]
#  [ 3.99141531]
#  [ 8.95955812]
#  [ 6.95377521]
#  [ 6.08950464]
#  [ 3.92659772]
#  [ 8.30170295]
#  [ 9.88547453]
#  [ 9.02576806]
#  [ 4.18986085]
#  [ 8.68093288]
#  [ 5.59642232]
#  [ 5.05860517]
#  [ 6.8764607 ]
#  [10.03532818]
#  [ 5.01123325]
#  [ 8.63889099]
#  [ 8.74588327]
#  [ 4.44437616]
#  [ 6.77886287]
#  [ 3.89448394]
#  [ 4.82309061]
#  [ 4.21788247]
#  [ 8.26179417]
#  [ 7.78049719]
#  [ 6.53822204]
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-4df5b4bc7279> in <cell line: 0>()
# ----> 1 LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
# TypeError: LinearRegression.__init__() got an unexpected keyword argument 'normalize'
